# %%
from importlib import reload
import models.models as mods
reload(mods)
import models.models as mods
# Out:
# 2025-06-24 12:53:13.673620: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-24 12:53:13.745710: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-24 12:53:13.746976: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-24 12:53:16.904904: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2025-06-24 12:53:26.125763: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
ae = mods.AE()
# ae.model_params
ae.run_train(named_experiment="AML", quick=True)
# Out:
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Parent folder: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits
# Save model set to: True
# Number of batches: 19
# Ordered batches (donors): ['AML1012', 'AML210A', 'AML328', 'AML329', 'AML419A', 'AML420B', 'AML475', 'AML556', 'AML707B', 'AML870', 'AML916', 'AML921A', 'BM1', 'BM2', 'BM3', 'BM4', 'BM5', 'MUTZ3', 'OCI']
#
#
# Running Fold 1
#
#
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
# Current Model Parameters:
# optimizer: <keras.src.optimizers.legacy.adam.Adam object at 0x2aac0fee5370>
# loss: [<keras.src.losses.MeanSquaredError object at 0x2aaab63fd820>]
# loss_weights: 1
# metrics: [[<keras.src.metrics.regression_metrics.MeanSquaredError object at 0x2aaab6ccad00>]]
# name: ae
# n_latent_dims: 2
# layer_units: [512, 132]
# last_activation: linear
# use_batch_norm: True
# eval_test: True
# use_z: False
# get_pred: False
# scaling: min_max
# fold_list: [1]
# model_type: ae
# batch_size: 512
# epochs: 3
# monitor_metric: val_loss
# patience: 30
# stop_criteria: early_stopping
# compute_latents_callback: False
# sample_size: 10000
# encoder_latent_name: None
# get_pca: True
# n_components: 2
# get_baseline: False
# batch_col: batch
# bio_col: celltype
# run_name: run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53
# model_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53
# plots_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53
# latent_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53
# model_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
# plots_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
# latent_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
# checkpoint_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1/cp-{epoch:04d}.ckpt
# checkpoint_dir: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_12-53/splits_1
#
# input_path_dict:
#  {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# input path dict {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train
# X.shape before scaling (23049, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val
# X.shape before scaling (7684, 2916)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# X.shape before scaling (7684, 2916)
# loaded adata, adata_dict keys check: dict_keys(['train', 'val', 'test'])
# Batches available:  ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# check that the shapes make sense
# train out shape x: (23049, 2916)
# val out shape x: (7684, 2916)
# train in shape x: (23049, 2916)
# val in shape x: (7684, 2916)
# train_in shape x: (23049, 2916)
# train_out shape x: (23049, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Tue Jun 24 12:53:28 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             30W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             24W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
# Epoch 1/3

# %%
aec = mods.AEC()
aec.run_train(named_experiment="AML", quick=True)
# Out:
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Parent folder: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits
# Save model set to: True
# Number of batches: 19
# Ordered batches (donors): ['AML1012', 'AML210A', 'AML328', 'AML329', 'AML419A', 'AML420B', 'AML475', 'AML556', 'AML707B', 'AML870', 'AML916', 'AML921A', 'BM1', 'BM2', 'BM3', 'BM4', 'BM5', 'MUTZ3', 'OCI']
#
#
# Running Fold 1
#
#
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
# Current Model Parameters:
# optimizer: <keras.src.optimizers.legacy.adam.Adam object at 0x2aae4d85cee0>
# loss: {'reconstruction_output': <keras.src.losses.MeanSquaredError object at 0x2aae4d85c4c0>, 'classification_output': <keras.src.losses.CategoricalCrossentropy object at 0x2aae4d85ca30>}
# loss_weights: {'reconstruction_output': 100, 'classification_output': 0.1}
# metrics: {'reconstruction_output': [<keras.src.metrics.regression_metrics.MeanSquaredError object at 0x2aae4d8b4760>], 'classification_output': [<keras.src.metrics.accuracy_metrics.CategoricalAccuracy object at 0x2aae4d5a9550>]}
# name: aec
# n_latent_dims: 2
# layer_units: [512, 132]
# layer_units_latent_classifier: [2]
# n_pred: 21
# last_activation: linear
# use_batch_norm: True
# eval_test: True
# use_z: False
# get_pred: True
# scaling: min_max
# fold_list: [1]
# model_type: aec
# batch_size: 512
# epochs: 3
# monitor_metric: val_loss
# patience: 30
# stop_criteria: early_stopping
# compute_latents_callback: False
# sample_size: 10000
# encoder_latent_name: None
# get_pca: True
# n_components: 2
# get_baseline: False
# batch_col: batch
# bio_col: celltype
# run_name: run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46
# model_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46
# plots_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46
# latent_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46
# model_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
# plots_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
# latent_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
# checkpoint_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1/cp-{epoch:04d}.ckpt
# checkpoint_dir: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1
#
# input_path_dict:
#  {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# input path dict {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train
# X.shape before scaling (23049, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val
# X.shape before scaling (7684, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test
# X.shape before scaling (7684, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# loaded adata, adata_dict keys check: dict_keys(['train', 'val', 'test'])
# Batches available:  ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# check that the shapes make sense
# train out shapes x,y: (23049, 2916) (23049, 21)
# val out shapes x,y: (7684, 2916) (7684, 21)
# train in shape x: (23049, 2916)
# val in shape x: (7684, 2916)
# train_in shape x: (23049, 2916)
# train_out shapes (x, y): (23049, 2916) , (23049, 21)
# Tue Jun 24 12:46:55 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             30W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             25W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
# Epoch 1/3
# 44/46 [===========================>..] - ETA: 0s - loss: 0.8369 - classification_output_loss: 3.0435 - reconstruction_output_loss: 0.0053 - classification_output_cce_metric: 0.0490 - reconstruction_output_mse_metric: 0.0053
# Epoch 1: val_loss improved from inf to 0.52421, saving model to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1/cp-0001.ckpt
# 46/46 [==============================] - 3s 36ms/step - loss: 0.8305 - classification_output_loss: 3.0431 - reconstruction_output_loss: 0.0053 - classification_output_cce_metric: 0.0492 - reconstruction_output_mse_metric: 0.0053 - val_loss: 0.5242 - val_classification_output_loss: 3.0330 - val_reconstruction_output_loss: 0.0022 - val_classification_output_cce_metric: 0.0869 - val_reconstruction_output_mse_metric: 0.0022
# Epoch 2/3
# 44/46 [===========================>..] - ETA: 0s - loss: 0.5398 - classification_output_loss: 3.0024 - reconstruction_output_loss: 0.0024 - classification_output_cce_metric: 0.0674 - reconstruction_output_mse_metric: 0.0024
# Epoch 2: val_loss improved from 0.52421 to 0.50796, saving model to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1/cp-0002.ckpt
# 46/46 [==============================] - 1s 23ms/step - loss: 0.5395 - classification_output_loss: 3.0017 - reconstruction_output_loss: 0.0024 - classification_output_cce_metric: 0.0678 - reconstruction_output_mse_metric: 0.0024 - val_loss: 0.5080 - val_classification_output_loss: 3.0064 - val_reconstruction_output_loss: 0.0021 - val_classification_output_cce_metric: 0.0592 - val_reconstruction_output_mse_metric: 0.0021
# Epoch 3/3
# 46/46 [==============================] - ETA: 0s - loss: 0.5157 - classification_output_loss: 2.9539 - reconstruction_output_loss: 0.0022 - classification_output_cce_metric: 0.0699 - reconstruction_output_mse_metric: 0.0022
# Epoch 3: val_loss improved from 0.50796 to 0.48961, saving model to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1/cp-0003.ckpt
# 46/46 [==============================] - 1s 24ms/step - loss: 0.5157 - classification_output_loss: 2.9539 - reconstruction_output_loss: 0.0022 - classification_output_cce_metric: 0.0699 - reconstruction_output_mse_metric: 0.0022 - val_loss: 0.4896 - val_classification_output_loss: 2.9807 - val_reconstruction_output_loss: 0.0019 - val_classification_output_cce_metric: 0.0847 - val_reconstruction_output_mse_metric: 0.0019
# Tue Jun 24 12:47:02 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             30W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             25W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
#
# Adding early stopping params..
# Training stopped at epoch 0.
# Best epoch was -30, which corresponds to checkpoint -29
#
# Saving model..
# Model saved
#
# Total time to train and save model: 6.5627281665802 seconds
# Model: "aec"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  1564062
#
#  decoder (Decoder)           multiple                  1565046
#
#  latent_classifier (Classif  multiple                  69
#  ier)
#
# =================================================================
# Total params: 1567691 (5.98 MB)
# Trainable params: 1566403 (5.98 MB)
# Non-trainable params: 1288 (5.03 KB)
# _________________________________________________________________
# None
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_0 (Dense)             multiple                  1493504
#
#  dense_1 (Dense)             multiple                  67716
#
#  batch_norm_0 (BatchNormali  multiple                  2048
#  zation)
#
#  activation_2 (Activation)   multiple                  0
#
#  batch_norm_1 (BatchNormali  multiple                  528
#  zation)
#
#  activation_3 (Activation)   multiple                  0
#
#  dense_latent (Dense)        multiple                  266
#
# =================================================================
# Total params: 1564062 (5.97 MB)
# Trainable params: 1562774 (5.96 MB)
# Non-trainable params: 1288 (5.03 KB)
# _________________________________________________________________
# None
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1_t (TiedDenseTransp  multiple                  68228
#  ose)
#
#  dense_latent_t (TiedDenseT  multiple                  398
#  ranspose)
#
#  dense_out (TiedDenseTransp  multiple                  1496420
#  ose)
#
#  dense_0 (Dense)             multiple                  1493504
#
#  dense_1 (Dense)             multiple                  67716
#
#  dense_latent (Dense)        multiple                  266
#
# =================================================================
# Total params: 1565046 (5.97 MB)
# Trainable params: 1565046 (5.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Starting plots
# Loss plots completed
# History saved to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_12-46/splits_1/history.csv
#
# getting pca
# Calculating PCA ncomponents= 2
# plotting latent representation: X_pca_train
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_train
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# plotting latent representation: X_pca_val
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_val
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# plotting latent representation: X_pca_test
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_test
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Total PCA computation time: 20.905794143676758 seconds
#
# getting encoder
#
#
# Getting encoder latent space and clustering scores
# Subset: train
# Type of inputs: <class 'tensorflow.python.framework.ops.EagerTensor'>
# use_layer_activations: False
# 46/46 [==============================] - 0s 5ms/step
#
# Latent_representation retrived using the encoder: None_train
#
# Plotting latent space
# plotting latent representation: None_train
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: None_train
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Finished plots
# Subset: val
# Type of inputs: <class 'tensorflow.python.framework.ops.EagerTensor'>
# use_layer_activations: False
# 16/16 [==============================] - 0s 4ms/step
#
# Latent_representation retrived using the encoder: None_val
#
# Plotting latent space
# plotting latent representation: None_val
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: None_val
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Finished plots
# Subset: test
# Type of inputs: <class 'tensorflow.python.framework.ops.EagerTensor'>
# use_layer_activations: False
# 16/16 [==============================] - 0s 4ms/step
#
# Latent_representation retrived using the encoder: None_test
#
# Plotting latent space
# plotting latent representation: None_test
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: None_test
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Finished plots
# 46/46 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 7ms/step
#
# Computing reconstruction for  train
# train std of X: [0.05357488 0.04506018 0.05864308 ... 0.05317942 0.05146347 0.05687795]
# train Mean of std of X: 0.048681937
# train std of recon(X): [0.00954676 0.01019005 0.01010177 ... 0.01137459 0.00935736 0.00979259]
# Mean of std of recon(X): 0.010682298
#
# Computing reconstruction for  val
# val std of X: [0.04325128 0.0582025  0.04271549 ... 0.04917807 0.04846825 0.05484955]
# val Mean of std of X: 0.046650946
# val std of recon(X): [0.01197951 0.0101678  0.01052088 ... 0.01135922 0.01266115 0.01027048]
# Mean of std of recon(X): 0.010584772
#
# Computing reconstruction for  test
# test std of X: [0.06110225 0.04143671 0.05034595 ... 0.04932574 0.06116887 0.04609562]
# test Mean of std of X: 0.049573634
# test std of recon(X): [0.01052279 0.00964964 0.01010941 ... 0.01098938 0.00955853 0.01190809]
# Mean of std of recon(X): 0.010745492
# Output fold adata {'train': AnnData object with n_obs × n_vars = 23049 × 2916
#     obs: 'Unnamed: 0.2', 'Unnamed: 0', 'Unnamed: 0.1', 'Cell', 'NumberOfReads', 'AlignedToGenome', 'AlignedToTranscriptome', 'TranscriptomeUMIs', 'NumberOfGenes', 'CyclingScore', 'CyclingBinary', 'MutTranscripts', 'WtTranscripts', 'PredictionRF2', 'PredictionRefined', 'CellType', 'Score_HSC', 'Score_Prog', 'Score_GMP', 'Score_ProMono', 'Score_Mono', 'Score_cDC', 'Score_pDC', 'Score_earlyEry', 'Score_lateEry', 'Score_ProB', 'Score_B', 'Score_Plasma', 'Score_T', 'Score_CTL', 'Score_NK', 'NanoporeTranscripts', 'id', 'Day', 'unique_id', 'Patient_group', 'celltype', 'batch', 'n_genes', 'original_index'
#     var: 'Unnamed: 0'
#     uns: 'pca'
#     obsm: 'X_pca_train', 'None_train', 'val': AnnData object with n_obs × n_vars = 7684 × 2916
#     obs: 'Unnamed: 0.2', 'Unnamed: 0', 'Unnamed: 0.1', 'Cell', 'NumberOfReads', 'AlignedToGenome', 'AlignedToTranscriptome', 'TranscriptomeUMIs', 'NumberOfGenes', 'CyclingScore', 'CyclingBinary', 'MutTranscripts', 'WtTranscripts', 'PredictionRF2', 'PredictionRefined', 'CellType', 'Score_HSC', 'Score_Prog', 'Score_GMP', 'Score_ProMono', 'Score_Mono', 'Score_cDC', 'Score_pDC', 'Score_earlyEry', 'Score_lateEry', 'Score_ProB', 'Score_B', 'Score_Plasma', 'Score_T', 'Score_CTL', 'Score_NK', 'NanoporeTranscripts', 'id', 'Day', 'unique_id', 'Patient_group', 'celltype', 'batch', 'n_genes', 'original_index'
#     var: 'Unnamed: 0'
#     uns: 'pca'
#     obsm: 'X_pca_val', 'None_val', 'test': AnnData object with n_obs × n_vars = 7684 × 2916
#     obs: 'Unnamed: 0.2', 'Unnamed: 0', 'Unnamed: 0.1', 'Cell', 'NumberOfReads', 'AlignedToGenome', 'AlignedToTranscriptome', 'TranscriptomeUMIs', 'NumberOfGenes', 'CyclingScore', 'CyclingBinary', 'MutTranscripts', 'WtTranscripts', 'PredictionRF2', 'PredictionRefined', 'CellType', 'Score_HSC', 'Score_Prog', 'Score_GMP', 'Score_ProMono', 'Score_Mono', 'Score_cDC', 'Score_pDC', 'Score_earlyEry', 'Score_lateEry', 'Score_ProB', 'Score_B', 'Score_Plasma', 'Score_T', 'Score_CTL', 'Score_NK', 'NanoporeTranscripts', 'id', 'Day', 'unique_id', 'Patient_group', 'celltype', 'batch', 'n_genes', 'original_index'
#     var: 'Unnamed: 0'
#     uns: 'pca'
#     obsm: 'X_pca_test', 'None_test'}
#
#
# Total time for training all folds and getting latent spaces: 54.440956354141235 seconds
# Loss plots completed
# Pipeline finished running for all folds
#
#
# Computing scores for different sampel sizes
# sample size 10000
#
# Started iteration through the folds to calculate scores..
#
#
# Processing clustering scores ['X_pca_train', 'None_train'] for dataset train in fold 1..
# Computing scores..
# sample_size: 10000
#
# DB: lower values --> better clustering
# 1/DB, CH, Silhouette: higher values --> better clustering
# Total computation time: 4.647281169891357 seconds
# Time per score for batch - DB: 0.0114, CH: 0.0046, Silhouette: 2.3141 seconds
# Time per score for celltype - DB: 0.0124, CH: 0.0048, Silhouette: 2.2973 seconds
# Computing scores..
# sample_size: 10000
#
# DB: lower values --> better clustering
# 1/DB, CH, Silhouette: higher values --> better clustering
# Total computation time: 4.586679458618164 seconds
# Time per score for batch - DB: 0.0114, CH: 0.0046, Silhouette: 2.3252 seconds
# Time per score for celltype - DB: 0.0130, CH: 0.0049, Silhouette: 2.2254 seconds
# Scores calculated for ['X_pca_train', 'None_train'] on train dataset in fold 1
#
#
# Processing clustering scores ['X_pca_val', 'None_val'] for dataset val in fold 1..
# Computing scores..
# sample_size: 10000
#
# DB: lower values --> better clustering
# 1/DB, CH, Silhouette: higher values --> better clustering
# Total computation time: 2.8337857723236084 seconds
# Time per score for batch - DB: 0.0108, CH: 0.0037, Silhouette: 1.4595 seconds
# Time per score for celltype - DB: 0.0117, CH: 0.0039, Silhouette: 1.3434 seconds
# Computing scores..
# sample_size: 10000
#
# DB: lower values --> better clustering
# 1/DB, CH, Silhouette: higher values --> better clustering
# Total computation time: 2.705143451690674 seconds
# Time per score for batch - DB: 0.0110, CH: 0.0036, Silhouette: 1.2890 seconds
# Time per score for celltype - DB: 0.0119, CH: 0.0039, Silhouette: 1.3850 seconds
# Scores calculated for ['X_pca_val', 'None_val'] on val dataset in fold 1
#
#
# Processing clustering scores ['X_pca_test', 'None_test'] for dataset test in fold 1..
# Computing scores..
# sample_size: 10000
#
# DB: lower values --> better clustering
# 1/DB, CH, Silhouette: higher values --> better clustering
# Total computation time: 2.6319398880004883 seconds
# Time per score for batch - DB: 0.0105, CH: 0.0037, Silhouette: 1.2741 seconds
# Time per score for celltype - DB: 0.0113, CH: 0.0039, Silhouette: 1.3279 seconds
# Computing scores..
# sample_size: 10000
#
# DB: lower values --> better clustering
# 1/DB, CH, Silhouette: higher values --> better clustering
# Total computation time: 2.8480677604675293 seconds
# Time per score for batch - DB: 0.0106, CH: 0.0037, Silhouette: 1.3722 seconds
# Time per score for celltype - DB: 0.0117, CH: 0.0038, Silhouette: 1.4454 seconds
# Scores calculated for ['X_pca_test', 'None_test'] on test dataset in fold 1
#
# Scores obtained for all folds
#
#
# Total computation time for clustering scores: 20.287736654281616 seconds
# Averaging scores for  train
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x2aac06f60d30>
#                    batch                          celltype            \
#                       ch      1/db silhouette           ch      1/db
# dataset_type
# None_train    237.600284  0.036129  -0.282154  1092.202426  0.149713
# X_pca_train   209.491418  0.079630  -0.287975  3285.374655  0.127021
#
#                         fold
#              silhouette
# dataset_type
# None_train    -0.097438  1.0
# X_pca_train   -0.087805  1.0
#              batch                 celltype                 fold
#                 ch 1/db silhouette       ch 1/db silhouette
# dataset_type
# None_train     NaN  NaN        NaN      NaN  NaN        NaN  NaN
# X_pca_train    NaN  NaN        NaN      NaN  NaN        NaN  NaN
#
# Summary scores for all 5 folds:
#                      mean                                              \
#                    batch                          celltype
#                       ch      1/db silhouette           ch      1/db
# dataset_type
# None_train    237.600284  0.036129  -0.282154  1092.202426  0.149713
# X_pca_train   209.491418  0.079630  -0.287975  3285.374655  0.127021
#
#                                std                  ...                      \
#                         fold batch                  ... celltype
#              silhouette         ch 1/db silhouette  ...     1/db silhouette
# dataset_type                                        ...
# None_train    -0.097438  1.0   NaN  NaN        NaN  ...      NaN        NaN
# X_pca_train   -0.087805  1.0   NaN  NaN        NaN  ...      NaN        NaN
#
#                         sem                                                \
#              fold sem_batch                         sem_celltype
#                      sem_ch sem_1/db sem_silhouette       sem_ch sem_1/db
# dataset_type
# None_train    NaN       NaN      NaN            NaN          NaN      NaN
# X_pca_train   NaN       NaN      NaN            NaN          NaN      NaN
#
#
#                             sem_fold
#              sem_silhouette     sem_
# dataset_type
# None_train              NaN      NaN
# X_pca_train             NaN      NaN
#
# [2 rows x 21 columns]
# Averaging scores for  val
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x2aae4d498af0>
#                    batch                          celltype            \
#                       ch      1/db silhouette           ch      1/db
# dataset_type
# None_val      183.971668  0.074133  -0.276127   820.411816  0.151764
# X_pca_val     157.494566  0.068251  -0.283454  2526.201933  0.146453
#
#                         fold
#              silhouette
# dataset_type
# None_val      -0.104015  1.0
# X_pca_val     -0.091927  1.0
#              batch                 celltype                 fold
#                 ch 1/db silhouette       ch 1/db silhouette
# dataset_type
# None_val       NaN  NaN        NaN      NaN  NaN        NaN  NaN
# X_pca_val      NaN  NaN        NaN      NaN  NaN        NaN  NaN
#
# Summary scores for all 5 folds:
#                      mean                                              \
#                    batch                          celltype
#                       ch      1/db silhouette           ch      1/db
# dataset_type
# None_val      183.971668  0.074133  -0.276127   820.411816  0.151764
# X_pca_val     157.494566  0.068251  -0.283454  2526.201933  0.146453
#
#                                std                  ...                      \
#                         fold batch                  ... celltype
#              silhouette         ch 1/db silhouette  ...     1/db silhouette
# dataset_type                                        ...
# None_val      -0.104015  1.0   NaN  NaN        NaN  ...      NaN        NaN
# X_pca_val     -0.091927  1.0   NaN  NaN        NaN  ...      NaN        NaN
#
#                         sem                                                \
#              fold sem_batch                         sem_celltype
#                      sem_ch sem_1/db sem_silhouette       sem_ch sem_1/db
# dataset_type
# None_val      NaN       NaN      NaN            NaN          NaN      NaN
# X_pca_val     NaN       NaN      NaN            NaN          NaN      NaN
#
#
#                             sem_fold
#              sem_silhouette     sem_
# dataset_type
# None_val                NaN      NaN
# X_pca_val               NaN      NaN
#
# [2 rows x 21 columns]
# Averaging scores for  test
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x2aadd37f1a30>
#                    batch                          celltype            \
#                       ch      1/db silhouette           ch      1/db
# dataset_type
# None_test     187.990346  0.068592  -0.273355   823.181665  0.170976
# X_pca_test    157.974816  0.055432  -0.285445  2628.787178  0.131133
#
#                         fold
#              silhouette
# dataset_type
# None_test     -0.099273  1.0
# X_pca_test    -0.083133  1.0
#              batch                 celltype                 fold
#                 ch 1/db silhouette       ch 1/db silhouette
# dataset_type
# None_test      NaN  NaN        NaN      NaN  NaN        NaN  NaN
# X_pca_test     NaN  NaN        NaN      NaN  NaN        NaN  NaN
#
# Summary scores for all 5 folds:
#                      mean                                              \
#                    batch                          celltype
#                       ch      1/db silhouette           ch      1/db
# dataset_type
# None_test     187.990346  0.068592  -0.273355   823.181665  0.170976
# X_pca_test    157.974816  0.055432  -0.285445  2628.787178  0.131133
#
#                                std                  ...                      \
#                         fold batch                  ... celltype
#              silhouette         ch 1/db silhouette  ...     1/db silhouette
# dataset_type                                        ...
# None_test     -0.099273  1.0   NaN  NaN        NaN  ...      NaN        NaN
# X_pca_test    -0.083133  1.0   NaN  NaN        NaN  ...      NaN        NaN
#
#                         sem                                                \
#              fold sem_batch                         sem_celltype
#                      sem_ch sem_1/db sem_silhouette       sem_ch sem_1/db
# dataset_type
# None_test     NaN       NaN      NaN            NaN          NaN      NaN
# X_pca_test    NaN       NaN      NaN            NaN          NaN      NaN
#
#
#                             sem_fold
#              sem_silhouette     sem_
# dataset_type
# None_test               NaN      NaN
# X_pca_test              NaN      NaN
#
# [2 rows x 21 columns]

# %%
da = mods.scMEDALFE()
da.run_train(named_experiment="AML", quick=True)
# Out:
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Parent folder: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits
# Save model set to: True
# Number of batches: 19
# Ordered batches (donors): ['AML1012', 'AML210A', 'AML328', 'AML329', 'AML419A', 'AML420B', 'AML475', 'AML556', 'AML707B', 'AML870', 'AML916', 'AML921A', 'BM1', 'BM2', 'BM3', 'BM4', 'BM5', 'MUTZ3', 'OCI']
#
#
# Running Fold 1
#
#
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
# Current Model Parameters:
# loss_recon: <keras.src.losses.MeanSquaredError object at 0x2aad53fa10a0>
# loss_multiclass: <keras.src.losses.CategoricalCrossentropy object at 0x2aad53fa1220>
# metric_multiclass: CategoricalAccuracy(name=acc,dtype=float32)
# opt_autoencoder: <keras.src.optimizers.legacy.adam.Adam object at 0x2aaab4e649d0>
# opt_adversary: <keras.src.optimizers.legacy.adam.Adam object at 0x2aad53fa1550>
# loss_gen_weight: 1
# loss_recon_weight: 4000
# loss_class_weight: 1
# name: scmedalfe
# n_latent_dims: 2
# layer_units: [512, 132]
# n_clusters: 19
# last_activation: linear
# use_batch_norm: True
# eval_test: True
# use_z: True
# get_pred: False
# scaling: min_max
# fold_list: [1]
# model_type: scmedalfe
# batch_size: 512
# epochs: 3
# monitor_metric: val_loss
# patience: 30
# stop_criteria: early_stopping
# compute_latents_callback: False
# sample_size: 10000
# encoder_latent_name: None
# get_pca: True
# n_components: 2
# get_baseline: False
# batch_col: batch
# bio_col: celltype
# run_name: run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48
# model_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48
# plots_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48
# latent_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48
# model_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
# plots_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
# latent_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
# checkpoint_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1/cp-{epoch:04d}.ckpt
# checkpoint_dir: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1
#
# input_path_dict:
#  {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# input path dict {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train
# X.shape before scaling (23049, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val
# X.shape before scaling (7684, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test
# X.shape before scaling (7684, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# loaded adata, adata_dict keys check: dict_keys(['train', 'val', 'test'])
# Batches available:  ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# check that the shapes make sense
# train out shape x: (23049, 2916)
# val out shape x: (7684, 2916)
# train in shapes x,z: (23049, 2916) (23049, 19)
# val in shapes x,z: (7684, 2916) (7684, 19)
# train_in shapes (x, z): (23049, 2916) , (23049, 19)
# train_out shape x: (23049, 2916)
# Tue Jun 24 12:48:13 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             30W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             25W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
# Epoch 1/3
# 45/46 [============================>.] - ETA: 0s - recon_loss: 0.0039 - adv_loss: 2.3407 - total_loss: 13.4359 - acc: 0.3107WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 46/46 [==============================] - 3s 38ms/step - recon_loss: 0.0039 - adv_loss: 2.3184 - total_loss: 13.3356 - acc: 0.3108 - val_recon_loss: 0.0022 - val_adv_loss: 2.6965 - val_total_loss: 6.0974 - val_acc: 0.4399
# Epoch 2/3
# 43/46 [===========================>..] - ETA: 0s - recon_loss: 0.0023 - adv_loss: 1.5526 - total_loss: 7.6928 - acc: 0.5721WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 46/46 [==============================] - 1s 25ms/step - recon_loss: 0.0023 - adv_loss: 1.5498 - total_loss: 7.6854 - acc: 0.5733 - val_recon_loss: 0.0019 - val_adv_loss: 2.4128 - val_total_loss: 5.1998 - val_acc: 0.5765
# Epoch 3/3
# 46/46 [==============================] - ETA: 0s - recon_loss: 0.0020 - adv_loss: 1.2416 - total_loss: 6.8274 - acc: 0.6480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 46/46 [==============================] - 1s 26ms/step - recon_loss: 0.0020 - adv_loss: 1.2416 - total_loss: 6.8274 - acc: 0.6480 - val_recon_loss: 0.0017 - val_adv_loss: 2.0788 - val_total_loss: 4.6208 - val_acc: 0.6121
# Tue Jun 24 12:48:21 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             30W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             25W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
#
# Adding early stopping params..
# Training stopped at epoch 0.
# Best epoch was -30, which corresponds to checkpoint -29
#
# Saving model..
# Model saved
#
# Total time to train and save model: 7.359771013259888 seconds
# Model: "scmedalfe"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  1564062
#
#  decoder (Decoder)           multiple                  1565046
#
#  adversary (AdversarialClas  multiple                  401507
#  sifier)
#
# =================================================================
# Total params: 1969137 (7.51 MB)
# Trainable params: 1967841 (7.51 MB)
# Non-trainable params: 1296 (5.06 KB)
# _________________________________________________________________
# None
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_0 (Dense)             multiple                  1493504
#
#  dense_1 (Dense)             multiple                  67716
#
#  batch_norm_0 (BatchNormali  multiple                  2048
#  zation)
#
#  activation_4 (Activation)   multiple                  0
#
#  batch_norm_1 (BatchNormali  multiple                  528
#  zation)
#
#  activation_5 (Activation)   multiple                  0
#
#  dense_latent (Dense)        multiple                  266
#
# =================================================================
# Total params: 1564062 (5.97 MB)
# Trainable params: 1562774 (5.96 MB)
# Non-trainable params: 1288 (5.03 KB)
# _________________________________________________________________
# None
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1_t (TiedDenseTransp  multiple                  68228
#  ose)
#
#  dense_latent_t (TiedDenseT  multiple                  398
#  ranspose)
#
#  dense_out (TiedDenseTransp  multiple                  1496420
#  ose)
#
#  dense_0 (Dense)             multiple                  1493504
#
#  dense_1 (Dense)             multiple                  67716
#
#  dense_latent (Dense)        multiple                  266
#
# =================================================================
# Total params: 1565046 (5.97 MB)
# Trainable params: 1565046 (5.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Starting plots
# No training loss plotted. Type a valid model_type [ae_da, ae, ae_re,aec,mec]
# Loss plots completed
# History saved to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfe/run_crossval_loss_gen_weight-1_loss_recon_weight-4000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfe_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-48/splits_1/history.csv
#
# getting pca
# Calculating PCA ncomponents= 2
# plotting latent representation: X_pca_train
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_train
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# plotting latent representation: X_pca_val
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_val
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# plotting latent representation: X_pca_test
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_test
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Total PCA computation time: 21.501240730285645 seconds
#
# getting encoder
#
#
# Getting encoder latent space and clustering scores
# Subset: train
# Type of inputs: <class 'tensorflow.python.framework.ops.EagerTensor'>
# use_layer_activations: True
# 46/46 [==============================] - 0s 5ms/step
#
# Latent_representation retrived using the encoder: None_train
#
# Plotting latent space
# plotting latent representation: None_train
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: None_train
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Finished plots
# Subset: val
# Type of inputs: <class 'tensorflow.python.framework.ops.EagerTensor'>
# use_layer_activations: True
# 16/16 [==============================] - 0s 6ms/step
#
# Latent_representation retrived using the encoder: None_val
#
# Plotting latent space
# plotting latent representation: None_val
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: None_val
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Finished plots
# Subset: test
# Type of inputs: <class 'tensorflow.python.framework.ops.EagerTensor'>
# use_layer_activations: True
# 16/16 [==============================] - 0s 5ms/step
#
# Latent_representation retrived using the encoder: None_test
#
# Plotting latent space
# plotting latent representation: None_test
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: None_test
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Finished plots
# 46/46 [==============================] - 1s 9ms/step
# 16/16 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 7ms/step
#
# Computing reconstruction for  train
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 da = mods.scMEDALFE()
# ----> 2 da.run_train(named_experiment="AML", quick=True)
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/models/base.py:168, in Model.run_train(self, data_path, outputs_path, named_experiment, save_model, quick, plotconfigs, plot_kwargs)
#     162 celltype_ids = np.unique(metadata_all[params.bio_col]).tolist()
#     164 # --------------------------------------------------------------------------------------
#     165 # 3. Run All Folds
#     166 # --------------------------------------------------------------------------------------
#     167 # Run folds and compute clustering metrics
# --> 168 mean_scores = run_all_folds(
#     169     Model=self.alg,
#     170     input_base_path=splits_path,
#     171     out_base_paths_dict=base_paths_dict,
#     172     folds_list=params.fold_list,
#     173     run_name=params.run_name,
#     174     model_params_dict=self.model_params,
#     175     build_model_dict={k:v for k, v in self.model_configs._asdict().items() if k != "ignore"},
#     176     compile_dict=self.compile_configs,
#     177     save_model=save_model,
#     178     batch_col=params.batch_col,
#     179     bio_col=params.bio_col,
#     180     batch_col_categories=seen_donor_ids,
#     181     bio_col_categories=celltype_ids,
#     182     model_type=self.model_name,
#     183     issparse=False,
#     184     load_dense=False,
#     185     shape_color_dict=shape_color_dict,
#     186     sample_size=params.sample_size
#     187 )
#     189 # --------------------------------------------------------------------------------------
#     190 # 4. Save Configuration File
#     191 # --------------------------------------------------------------------------------------
#     192 destination_path = os.path.join(saved_models_base, params.run_name, "configs.json")
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:1474, in run_all_folds(Model, input_base_path, out_base_paths_dict, folds_list, run_name, model_params_dict, build_model_dict, compile_dict, save_model, batch_col, bio_col, batch_col_categories, bio_col_categories, model_type, issparse, load_dense, shape_color_dict, sample_size)
#    1469 print("\ninput_path_dict:\n", input_path_dict)
#    1470 # print("input_path_dict keys:", input_path_dict.keys())
#    1471
#    1472
#    1473 # Run pipeline for the current fold
# -> 1474 fold_results = run_model_pipeline(Model=Model,
#    1475                                   input_path_dict=input_path_dict,
#    1476                                   build_model_dict=build_model_dict,
#    1477                                   compile_dict=compile_dict,
#    1478                                   model_params=model_params,
#    1479                                   save_model=save_model,
#    1480                                   batch_col=batch_col,
#    1481                                   bio_col=bio_col,
#    1482                                   batch_col_categories=batch_col_categories,
#    1483                                   bio_col_categories=bio_col_categories,
#    1484                                   return_scores=return_scores_temp,
#    1485                                   return_adata_dict=True,
#    1486                                   return_trained_model=False,
#    1487                                   model_type=model_type,
#    1488                                   issparse=issparse,
#    1489                                   load_dense=load_dense,
#    1490                                   shape_color_dict=shape_color_dict,
#    1491                                   sample_size = sample_size,
#    1492                                   return_history=True)
#    1494 # add adata dictionaries per fold to all_folds_adata dict
#    1495 print("Output fold adata",fold_results["adata"])
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:1354, in run_model_pipeline(Model, input_path_dict, build_model_dict, compile_dict, model_params, save_model, batch_col, bio_col, batch_col_categories, bio_col_categories, return_scores, return_adata_dict, return_trained_model, model_type, issparse, load_dense, shape_color_dict, sample_size, return_history)
#    1351     recon = output['recon']
#    1353 # Ensure recon is a numpy array
# -> 1354 if not isinstance(recon, np.ndarray):
#    1355     recon = np.array(recon)
#    1357 # Save recon outputs to a file at the specified latent path
#
# UnboundLocalError: local variable 'recon' referenced before assignment

# %%
da = mods.scMEDALFE(**{"n_latent_dims":50})
da.run_train(named_experiment="AML", quick=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 da = mods.scMEDALFE(**{"n_latent_dims":50})
#       2 da.run_train(named_experiment="AML", quick=True)
#
# NameError: name 'mods' is not defined

# %%
dac = mods.scMEDALFEC()
dac.run_train(named_experiment="AML", quick=True)
# Out:
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Parent folder: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits
# Save model set to: True
# Number of batches: 19
# Ordered batches (donors): ['AML1012', 'AML210A', 'AML328', 'AML329', 'AML419A', 'AML420B', 'AML475', 'AML556', 'AML707B', 'AML870', 'AML916', 'AML921A', 'BM1', 'BM2', 'BM3', 'BM4', 'BM5', 'MUTZ3', 'OCI']
#
#
# Running Fold 1
#
#
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
# Current Model Parameters:
# loss_recon: <keras.src.losses.MeanSquaredError object at 0x2aac0ff3af70>
# loss_multiclass: <keras.src.losses.CategoricalCrossentropy object at 0x2aac0ff3afd0>
# metric_multiclass: CategoricalAccuracy(name=acc,dtype=float32)
# opt_autoencoder: <keras.src.optimizers.legacy.adam.Adam object at 0x2aaab63d16a0>
# opt_adversary: <keras.src.optimizers.legacy.adam.Adam object at 0x2aac0ff476d0>
# loss_gen_weight: 1
# loss_recon_weight: 2000
# loss_class_weight: 1
# name: scmedalfec
# n_latent_dims: 2
# layer_units: [512, 132]
# layer_units_latent_classifier: [2]
# n_pred: 21
# n_clusters: 19
# last_activation: linear
# use_batch_norm: True
# eval_test: True
# use_z: True
# get_pred: False
# scaling: min_max
# fold_list: [1]
# model_type: scmedalfec
# batch_size: 512
# epochs: 3
# monitor_metric: val_loss
# patience: 30
# stop_criteria: early_stopping
# compute_latents_callback: False
# sample_size: 10000
# encoder_latent_name: None
# get_pca: True
# n_components: 2
# get_baseline: False
# batch_col: batch
# bio_col: celltype
# run_name: run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39
# model_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39
# plots_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39
# latent_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39
# model_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
# plots_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/figures/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
# latent_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
# checkpoint_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1/cp-{epoch:04d}.ckpt
# checkpoint_dir: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1
#
# input_path_dict:
#  {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# input path dict {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train
# X.shape before scaling (23049, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val
# X.shape before scaling (7684, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test
# X.shape before scaling (7684, 2916)
# loaded adata, adata_dict keys check: dict_keys(['train', 'val', 'test'])
# Batches available:  ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# check that the shapes make sense
# train out shape x: (23049, 2916)
# val out shape x: (7684, 2916)
# train in shapes x,z: (23049, 2916) (23049, 19)
# val in shapes x,z: (7684, 2916) (7684, 19)
# train_in shapes (x, z): (23049, 2916) , (23049, 19)
# train_out shape x: (23049, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Tue Jun 24 12:40:00 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             31W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             24W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
# Epoch 1/3
# 43/46 [===========================>..] - ETA: 0s - recon_loss: 0.0038 - adv_loss: 2.3673 - total_loss: 5.3077 - acc: 0.2904WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 46/46 [==============================] - 4s 37ms/step - recon_loss: 0.0037 - adv_loss: 2.3375 - total_loss: 5.1671 - acc: 0.2984 - val_recon_loss: 0.0022 - val_adv_loss: 2.7178 - val_total_loss: 1.6751 - val_acc: 0.4149
# Epoch 2/3
# 46/46 [==============================] - ETA: 0s - recon_loss: 0.0023 - adv_loss: 1.7290 - total_loss: 2.9137 - acc: 0.5209WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 46/46 [==============================] - 1s 25ms/step - recon_loss: 0.0023 - adv_loss: 1.7290 - total_loss: 2.9137 - acc: 0.5209 - val_recon_loss: 0.0019 - val_adv_loss: 2.5090 - val_total_loss: 1.3545 - val_acc: 0.4991
# Epoch 3/3
# 46/46 [==============================] - ETA: 0s - recon_loss: 0.0020 - adv_loss: 1.6336 - total_loss: 2.4129 - acc: 0.5326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: recon_loss,adv_loss,total_loss,acc,val_recon_loss,val_adv_loss,val_total_loss,val_acc
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 46/46 [==============================] - 1s 25ms/step - recon_loss: 0.0020 - adv_loss: 1.6336 - total_loss: 2.4129 - acc: 0.5326 - val_recon_loss: 0.0017 - val_adv_loss: 2.3397 - val_total_loss: 1.0275 - val_acc: 0.4429
# Tue Jun 24 12:40:07 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             30W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             25W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
#
# Adding early stopping params..
# Training stopped at epoch 0.
# Best epoch was -30, which corresponds to checkpoint -29
#
# Saving model..
# Model saved
#
# Total time to train and save model: 7.2635838985443115 seconds
# Model: "scmedalfec"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  1564062
#
#  decoder (Decoder)           multiple                  1565046
#
#  adversary (AdversarialClas  multiple                  401507
#  sifier)
#
# =================================================================
# Total params: 1969137 (7.51 MB)
# Trainable params: 1967841 (7.51 MB)
# Non-trainable params: 1296 (5.06 KB)
# _________________________________________________________________
# None
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_0 (Dense)             multiple                  1493504
#
#  dense_1 (Dense)             multiple                  67716
#
#  batch_norm_0 (BatchNormali  multiple                  2048
#  zation)
#
#  activation (Activation)     multiple                  0
#
#  batch_norm_1 (BatchNormali  multiple                  528
#  zation)
#
#  activation_1 (Activation)   multiple                  0
#
#  dense_latent (Dense)        multiple                  266
#
# =================================================================
# Total params: 1564062 (5.97 MB)
# Trainable params: 1562774 (5.96 MB)
# Non-trainable params: 1288 (5.03 KB)
# _________________________________________________________________
# None
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1_t (TiedDenseTransp  multiple                  68228
#  ose)
#
#  dense_latent_t (TiedDenseT  multiple                  398
#  ranspose)
#
#  dense_out (TiedDenseTransp  multiple                  1496420
#  ose)
#
#  dense_0 (Dense)             multiple                  1493504
#
#  dense_1 (Dense)             multiple                  67716
#
#  dense_latent (Dense)        multiple                  266
#
# =================================================================
# Total params: 1565046 (5.97 MB)
# Trainable params: 1565046 (5.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Starting plots
# No training loss plotted. Type a valid model_type [ae_da, ae, ae_re,aec,mec]
# Loss plots completed
# History saved to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/latent_space/log_transformed_2916hvggenes/scmedalfec/run_crossval_loss_gen_weight-1_loss_recon_weight-2000_loss_class_weight-1_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-scmedalfec_batch_size-512_epochs-500_patience-30_sample_size-10000_2025-06-24_12-39/splits_1/history.csv
#
# getting pca
# Calculating PCA ncomponents= 2
# plotting latent representation: X_pca_train
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_train
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# plotting latent representation: X_pca_val
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_val
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# plotting latent representation: X_pca_test
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_test
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Total PCA computation time: 21.738677501678467 seconds
#
# getting encoder
#
#
# Getting encoder latent space and clustering scores
# Subset: train
# Type of inputs: <class 'tensorflow.python.framework.ops.EagerTensor'>
# use_layer_activations: True
# 46/46 [==============================] - 0s 7ms/step
#
# Latent_representation retrived using the encoder: None_train
#
# Plotting latent space
# plotting latent representation: None_train
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: None_train
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Finished plots
# Subset: val
# Type of inputs: <class 'tensorflow.python.framework.ops.EagerTensor'>
# use_layer_activations: True
# 16/16 [==============================] - 0s 7ms/step
#
# Latent_representation retrived using the encoder: None_val
#
# Plotting latent space
# plotting latent representation: None_val
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: None_val
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Finished plots
# Subset: test
# Type of inputs: <class 'tensorflow.python.framework.ops.EagerTensor'>
# use_layer_activations: True
# 16/16 [==============================] - 0s 5ms/step
#
# Latent_representation retrived using the encoder: None_test
#
# Plotting latent space
# plotting latent representation: None_test
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: None_test
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# Finished plots
# 46/46 [==============================] - 1s 9ms/step
# 16/16 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 7ms/step
#
# Computing reconstruction for  train
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 dac = mods.scMEDALFEC()
# ----> 2 dac.run_train(named_experiment="AML", quick=True)
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/models/base.py:168, in Model.run_train(self, data_path, outputs_path, named_experiment, save_model, quick, plotconfigs, plot_kwargs)
#     162 celltype_ids = np.unique(metadata_all[params.bio_col]).tolist()
#     164 # --------------------------------------------------------------------------------------
#     165 # 3. Run All Folds
#     166 # --------------------------------------------------------------------------------------
#     167 # Run folds and compute clustering metrics
# --> 168 mean_scores = run_all_folds(
#     169     Model=self.alg,
#     170     input_base_path=splits_path,
#     171     out_base_paths_dict=base_paths_dict,
#     172     folds_list=params.fold_list,
#     173     run_name=params.run_name,
#     174     model_params_dict=self.model_params,
#     175     build_model_dict={k:v for k, v in self.model_configs._asdict().items() if k != "ignore"},
#     176     compile_dict=self.compile_configs,
#     177     save_model=save_model,
#     178     batch_col=params.batch_col,
#     179     bio_col=params.bio_col,
#     180     batch_col_categories=seen_donor_ids,
#     181     bio_col_categories=celltype_ids,
#     182     model_type=self.model_name,
#     183     issparse=False,
#     184     load_dense=False,
#     185     shape_color_dict=shape_color_dict,
#     186     sample_size=params.sample_size
#     187 )
#     189 # --------------------------------------------------------------------------------------
#     190 # 4. Save Configuration File
#     191 # --------------------------------------------------------------------------------------
#     192 destination_path = os.path.join(saved_models_base, params.run_name, "configs.json")
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:1474, in run_all_folds(Model, input_base_path, out_base_paths_dict, folds_list, run_name, model_params_dict, build_model_dict, compile_dict, save_model, batch_col, bio_col, batch_col_categories, bio_col_categories, model_type, issparse, load_dense, shape_color_dict, sample_size)
#    1469 print("\ninput_path_dict:\n", input_path_dict)
#    1470 # print("input_path_dict keys:", input_path_dict.keys())
#    1471
#    1472
#    1473 # Run pipeline for the current fold
# -> 1474 fold_results = run_model_pipeline(Model=Model,
#    1475                                   input_path_dict=input_path_dict,
#    1476                                   build_model_dict=build_model_dict,
#    1477                                   compile_dict=compile_dict,
#    1478                                   model_params=model_params,
#    1479                                   save_model=save_model,
#    1480                                   batch_col=batch_col,
#    1481                                   bio_col=bio_col,
#    1482                                   batch_col_categories=batch_col_categories,
#    1483                                   bio_col_categories=bio_col_categories,
#    1484                                   return_scores=return_scores_temp,
#    1485                                   return_adata_dict=True,
#    1486                                   return_trained_model=False,
#    1487                                   model_type=model_type,
#    1488                                   issparse=issparse,
#    1489                                   load_dense=load_dense,
#    1490                                   shape_color_dict=shape_color_dict,
#    1491                                   sample_size = sample_size,
#    1492                                   return_history=True)
#    1494 # add adata dictionaries per fold to all_folds_adata dict
#    1495 print("Output fold adata",fold_results["adata"])
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:1354, in run_model_pipeline(Model, input_path_dict, build_model_dict, compile_dict, model_params, save_model, batch_col, bio_col, batch_col_categories, bio_col_categories, return_scores, return_adata_dict, return_trained_model, model_type, issparse, load_dense, shape_color_dict, sample_size, return_history)
#    1351     recon = output['recon']
#    1353 # Ensure recon is a numpy array
# -> 1354 if not isinstance(recon, np.ndarray):
#    1355     recon = np.array(recon)
#    1357 # Save recon outputs to a file at the specified latent path
#
# UnboundLocalError: local variable 'recon' referenced before assignment
