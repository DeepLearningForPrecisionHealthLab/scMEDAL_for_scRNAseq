# %% [markdown]
# ## AML Data Processing Notebook
#
# This notebook processes the AML dataset obtained from [GEO (GSE116256)](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE116256) and saves it as a single count matrix.
#
# ### Data Sources
# - The count matrix and annotations were downloaded from [GEO (GSE116256)](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE116256).
# - The compressed files are stored in:
#   `/scMEDAL_for_scRNAseq/Experiments/data/AML_data/zip_files`
# - The processed count matrix is saved in:
#   `/scMEDAL_for_scRNAseq/Experiments/data/AML_data/adata_merged`

# %%
import sys
# Add the parent directory to the Python path
sys.path.append("../")
import os
# Now you can import from the parent directory
from paths_config import data_base_path

from scMEDAL.utils.preprocessing_utils import AML_data_reader
from scMEDAL.utils.utils import save_adata

# %%
# I downloaded the dataset count matrix and annotations from: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE116256
# I saved the compressed files under /scMEDAL_for_scRNAseq/Experiments/data/AML_data/zip_files
# Path to the directory containing zip files
parent_path = os.path.join(data_base_path, "zip_files")
# 1.Read adata


AML_reader = AML_data_reader(parent_path)
# Get df_paths
df_paths = AML_reader.get_df_paths()
df_paths
# Out:
#          id Patient_group  counts
# 0   AML1012           AML       1
# 1   AML210A           AML       1
# 2    AML314           AML       2
# 3    AML328           AML       4
# 4    AML329           AML       3
# 5    AML371           AML       2
# 6   AML419A           AML       1
# 7   AML420B           AML       3
# 8    AML475           AML       2
# 9    AML556           AML       3
# 10  AML707B           AML       5
# 11  AML722B           AML       2
# 12   AML870           AML       2
# 13   AML916           AML       1
# 14  AML921A           AML       1
# 15   AML997           AML       2
# 16      BM1       control       1
# 17      BM2       control       1
# 18      BM3       control       1
# 19      BM4       control       1
# 20      BM5       control       2
# 21    MUTZ3      cellline       1
# 22      OCI      cellline       1
#                                           matrix_path       id   file_note  \
# 0   /archive/bioinformatics/DLLab/AixaAndrade/data...   AML328          D0
# 1   /archive/bioinformatics/DLLab/AixaAndrade/data...  AML420B         D14
# 2   /archive/bioinformatics/DLLab/AixaAndrade/data...   AML314          D0
# 3   /archive/bioinformatics/DLLab/AixaAndrade/data...   AML556         D15
# 4   /archive/bioinformatics/DLLab/AixaAndrade/data...   AML314         D31
# 5   /archive/bioinformatics/DLLab/AixaAndrade/data...   AML371         D34
# 6   /archive/bioinformatics/DLLab/AixaAndrade/data...  AML210A          D0
# 7   /archive/bioinformatics/DLLab/AixaAndrade/data...  AML707B         D41
# 8   /archive/bioinformatics/DLLab/AixaAndrade/data...   AML475          D0
# 9   /archive/bioinformatics/DLLab/AixaAndrade/data...  AML707B        D113
# 10  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML328        D113
# 11  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML916          D0
# 12  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML329         D37
# 13  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML707B         D18
# 14  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML556          D0
# 15  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML997          D0
# 16  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML722B          D0
# 17  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML707B         D97
# 18  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML1012          D0
# 19  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML870          D0
# 20  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML329         D20
# 21  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML419A          D0
# 22  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML707B          D0
# 23  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML329          D0
# 24  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML556         D31
# 25  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML870         D14
# 26  /archive/bioinformatics/DLLab/AixaAndrade/data...      BM4         BM4
# 27  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML475         D29
# 28  /archive/bioinformatics/DLLab/AixaAndrade/data...      OCI         NaN
# 29  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML997         D35
# 30  /archive/bioinformatics/DLLab/AixaAndrade/data...      BM2         BM2
# 31  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML328         D29
# 32  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML420B         D35
# 33  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML921A          D0
# 34  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML420B          D0
# 35  /archive/bioinformatics/DLLab/AixaAndrade/data...      BM3         BM3
# 36  /archive/bioinformatics/DLLab/AixaAndrade/data...      BM1         BM1
# 37  /archive/bioinformatics/DLLab/AixaAndrade/data...      BM5  BM5-34p38n
# 38  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML371          D0
# 39  /archive/bioinformatics/DLLab/AixaAndrade/data...  AML722B         D49
# 40  /archive/bioinformatics/DLLab/AixaAndrade/data...    MUTZ3         NaN
# 41  /archive/bioinformatics/DLLab/AixaAndrade/data...      BM5     BM5-34p
# 42  /archive/bioinformatics/DLLab/AixaAndrade/data...   AML328        D171
#
#    accession_matrix_num                                          anno_path  \
# 0            GSM3587931  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 1            GSM3587955  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 2            GSM3587927  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 3            GSM3587965  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 4            GSM3587929  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 5            GSM3587948  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 6            GSM3587925  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 7            GSM3587975  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 8            GSM3587959  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 9            GSM3587971  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 10           GSM3587933  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 11           GSM3587988  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 12           GSM3587944  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 13           GSM3587973  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 14           GSM3587963  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 15           GSM3587992  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 16           GSM3587980  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 17           GSM3587977  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 18           GSM3587923  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 19           GSM3587984  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 20           GSM3587942  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 21           GSM3587950  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 22           GSM3587969  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 23           GSM3587940  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 24           GSM3587967  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 25           GSM3587986  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 26           GSM3588000  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 27           GSM3587961  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 28           GSM3588005  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 29           GSM3587994  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 30           GSM3587997  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 31           GSM3587937  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 32           GSM3587957  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 33           GSM3587990  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 34           GSM3587953  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 35           GSM3587998  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 36           GSM3587996  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 37           GSM3588003  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 38           GSM3587946  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 39           GSM3587982  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 40           GSM3588004  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 41           GSM3588002  /archive/bioinformatics/DLLab/AixaAndrade/data...
# 42           GSM3587935  /archive/bioinformatics/DLLab/AixaAndrade/data...
#
#    accession_anno_num   Day     unique_id Patient_group
# 0          GSM3587932    D0     AML328_D0           AML
# 1          GSM3587956   D14   AML420B_D14           AML
# 2          GSM3587928    D0     AML314_D0           AML
# 3          GSM3587966   D15    AML556_D15           AML
# 4          GSM3587930   D31    AML314_D31           AML
# 5          GSM3587949   D34    AML371_D34           AML
# 6          GSM3587926    D0    AML210A_D0           AML
# 7          GSM3587976   D41   AML707B_D41           AML
# 8          GSM3587960    D0     AML475_D0           AML
# 9          GSM3587972  D113  AML707B_D113           AML
# 10         GSM3587934  D113   AML328_D113           AML
# 11         GSM3587989    D0     AML916_D0           AML
# 12         GSM3587945   D37    AML329_D37           AML
# 13         GSM3587974   D18   AML707B_D18           AML
# 14         GSM3587964    D0     AML556_D0           AML
# 15         GSM3587993    D0     AML997_D0           AML
# 16         GSM3587981    D0    AML722B_D0           AML
# 17         GSM3587978   D97   AML707B_D97           AML
# 18         GSM3587924    D0    AML1012_D0           AML
# 19         GSM3587985    D0     AML870_D0           AML
# 20         GSM3587943   D20    AML329_D20           AML
# 21         GSM3587951    D0    AML419A_D0           AML
# 22         GSM3587970    D0    AML707B_D0           AML
# 23         GSM3587941    D0     AML329_D0           AML
# 24         GSM3587968   D31    AML556_D31           AML
# 25         GSM3587987   D14    AML870_D14           AML
# 26         GSM3588001   NaN           BM4       control
# 27         GSM3587962   D29    AML475_D29           AML
# 28         GSM3588005   NaN           OCI      cellline
# 29         GSM3587995   D35    AML997_D35           AML
# 30         GSM3587997   NaN           BM2       control
# 31         GSM3587938   D29    AML328_D29           AML
# 32         GSM3587958   D35   AML420B_D35           AML
# 33         GSM3587991    D0    AML921A_D0           AML
# 34         GSM3587954    D0    AML420B_D0           AML
# 35         GSM3587999   NaN           BM3       control
# 36         GSM3587996   NaN           BM1       control
# 37         GSM3588003   NaN    BM5-34p38n       control
# 38         GSM3587947    D0     AML371_D0           AML
# 39         GSM3587983   D49   AML722B_D49           AML
# 40         GSM3588004   NaN         MUTZ3      cellline
# 41         GSM3588002   NaN       BM5-34p       control
# 42         GSM3587936  D171   AML328_D171           AML

# %%
# Create a dict of adata objects
adata_dict = AML_reader.create_adata_dict(df_paths)
print(f"Created {len(adata_dict)} AnnData objects.")
# Out:
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/Aixa_scDML/lib/python3.8/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Created 43 AnnData objects.

# %%
merged_adata = AML_reader.merge_adata_objects(adata_dict)

# %%
merged_adata
# Out:
# AnnData object with n_obs × n_vars = 41090 × 27899
#     obs: 'Cell', 'NumberOfReads', 'AlignedToGenome', 'AlignedToTranscriptome', 'TranscriptomeUMIs', 'NumberOfGenes', 'CyclingScore', 'CyclingBinary', 'MutTranscripts', 'WtTranscripts', 'PredictionRF2', 'PredictionRefined', 'CellType', 'Score_HSC', 'Score_Prog', 'Score_GMP', 'Score_ProMono', 'Score_Mono', 'Score_cDC', 'Score_pDC', 'Score_earlyEry', 'Score_lateEry', 'Score_ProB', 'Score_B', 'Score_Plasma', 'Score_T', 'Score_CTL', 'Score_NK', 'NanoporeTranscripts', 'id', 'Day', 'unique_id', 'Patient_group'
#     var: 'Gene'

# %%
merged_adata.obs
# Out:
#                            Cell  NumberOfReads  AlignedToGenome  \
# 0        AML328-D0_AAAAACAGAAGT          24994            15391
# 1        AML328-D0_AAAACCGCTACT          55122            34633
# 2        AML328-D0_AAAACCGGCTTT          43393            26813
# 3        AML328-D0_AAAAGCTTATCA          25085            15404
# 4        AML328-D0_AAAAGTCCCCGT          54911            33226
# ...                         ...            ...              ...
# 41085  AML328-D171_CCATCATCCACC          26414            19298
# 41086  AML328-D171_TTTTATCATTCT          27460            20073
# 41087  AML328-D171_AAGATGTAGCGT          12394             8787
# 41088  AML328-D171_CTGTAGCTCCTA          19172            13904
# 41089  AML328-D171_GATTTGGACGTT          15912            11652
#
#        AlignedToTranscriptome  TranscriptomeUMIs  NumberOfGenes  CyclingScore  \
# 0                        7477               1236            581        -0.351
# 1                       17252               3394           1238        -0.409
# 2                       16148               2649           1243        -0.401
# 3                        9483               1582            633        -0.378
# 4                       20545               3280           1376        -0.629
# ...                       ...                ...            ...           ...
# 41085                   13674               2516            939        -0.257
# 41086                    9433               1651            878        -0.524
# 41087                    6543               1331            504        -0.348
# 41088                   10351               1792            745        -0.394
# 41089                    6120               1153            580        -0.310
#
#       CyclingBinary MutTranscripts WtTranscripts  ... Score_B Score_Plasma  \
# 0                no            NaN           NaN  ...   0.042        0.009
# 1                no            NaN           NaN  ...   0.071        0.020
# 2                no            NaN           NaN  ...   0.062        0.052
# 3                no            NaN           NaN  ...   0.060        0.009
# 4                no            NaN           NaN  ...   0.012        0.003
# ...             ...            ...           ...  ...     ...          ...
# 41085            no            NaN           NaN  ...   0.058        0.016
# 41086            no            NaN           NaN  ...   0.066        0.023
# 41087            no            NaN           NaN  ...   0.088        0.019
# 41088            no            NaN           NaN  ...   0.107        0.015
# 41089            no            NaN           NaN  ...   0.077        0.020
#
#       Score_T  Score_CTL  Score_NK  NanoporeTranscripts      id   Day  \
# 0       0.132      0.184     0.447                  NaN  AML328    D0
# 1       0.070      0.052     0.037                  NaN  AML328    D0
# 2       0.046      0.032     0.034                  NaN  AML328    D0
# 3       0.491      0.167     0.080                  NaN  AML328    D0
# 4       0.006      0.010     0.009                  NaN  AML328    D0
# ...       ...        ...       ...                  ...     ...   ...
# 41085   0.464      0.135     0.109                  NaN  AML328  D171
# 41086   0.281      0.226     0.213                  NaN  AML328  D171
# 41087   0.136      0.074     0.041                  NaN  AML328  D171
# 41088   0.121      0.045     0.052                  NaN  AML328  D171
# 41089   0.365      0.138     0.067                  NaN  AML328  D171
#
#          unique_id  Patient_group
# 0        AML328_D0            AML
# 1        AML328_D0            AML
# 2        AML328_D0            AML
# 3        AML328_D0            AML
# 4        AML328_D0            AML
# ...            ...            ...
# 41085  AML328_D171            AML
# 41086  AML328_D171            AML
# 41087  AML328_D171            AML
# 41088  AML328_D171            AML
# 41089  AML328_D171            AML
#
# [41090 rows x 33 columns]

# %%
# Change to True to save adata
# I saved the cmerged count matrix under /scMEDAL_for_scRNAseq/Experiments/data/AML_data/adata_merged
save_data = False
if save_data:
    #save merged adata
    save_adata(merged_adata,output_path=data_base_path+"/adata_merged")
# Out:
# Created folder: /archive/bioinformatics/DLLab/AixaAndrade/data/Genomic_data/VanGallen_2019/adata_merged
