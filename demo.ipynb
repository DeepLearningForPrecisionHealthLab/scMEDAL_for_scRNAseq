# %%
import os
from importlib import reload

import models.models as mods
ae = mods.AE()
# ae.model_params
ae.run_train(named_experiment="AML", quick=True)
# Out:
# 2025-06-24 11:35:03.573195: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-24 11:35:03.643050: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-24 11:35:03.644321: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-24 11:35:05.991316: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2025-06-24 11:35:14.832354: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Parent folder: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits
# Save model set to: True
# Number of batches: 19
# Ordered batches (donors): ['AML1012', 'AML210A', 'AML328', 'AML329', 'AML419A', 'AML420B', 'AML475', 'AML556', 'AML707B', 'AML870', 'AML916', 'AML921A', 'BM1', 'BM2', 'BM3', 'BM4', 'BM5', 'MUTZ3', 'OCI']
#
#
# Running Fold 1
#
#
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/figures/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/latent_space/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/figures/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/latent_space/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
# Current Model Parameters:
# optimizer: <keras.src.optimizers.legacy.adam.Adam object at 0x2aaab63d6400>
# loss: [<keras.src.losses.MeanSquaredError object at 0x2aac0ff36fd0>]
# loss_weights: 1
# metrics: [[<keras.src.metrics.regression_metrics.MeanSquaredError object at 0x2aac0ff36e20>]]
# name: ae
# n_latent_dims: 2
# layer_units: [512, 132]
# last_activation: linear
# use_batch_norm: True
# eval_test: True
# use_z: False
# get_pred: False
# scaling: min_max
# fold_list: [1, 2, 3, 4, 5]
# model_type: ae
# batch_size: 512
# epochs: 3
# monitor_metric: val_loss
# patience: 30
# stop_criteria: early_stopping
# compute_latents_callback: False
# sample_size: 10000
# encoder_latent_name: None
# get_pca: True
# n_components: 2
# get_baseline: False
# batch_col: batch
# bio_col: celltype
# run_name: run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35
# model_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35
# plots_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/figures/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35
# latent_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/latent_space/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35
# model_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
# plots_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/figures/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
# latent_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/latent_space/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
# checkpoint_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1/cp-{epoch:04d}.ckpt
# checkpoint_dir: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1
#
# input_path_dict:
#  {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# input path dict {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train
# X.shape before scaling (23049, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val
# X.shape before scaling (7684, 2916)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# X.shape before scaling (7684, 2916)
# loaded adata, adata_dict keys check: dict_keys(['train', 'val', 'test'])
# Batches available:  ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# check that the shapes make sense
# train out shape x: (23049, 2916)
# val out shape x: (7684, 2916)
# train in shape x: (23049, 2916)
# val in shape x: (7684, 2916)
# train_in shape x: (23049, 2916)
# train_out shape x: (23049, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Tue Jun 24 11:35:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             30W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             24W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
# Epoch 1/3
# 43/46 [===========================>..] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 1: val_loss improved from inf to 0.00221, saving model to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1/cp-0001.ckpt
# 46/46 [==============================] - 3s 36ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 2/3
# 43/46 [===========================>..] - ETA: 0s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 2: val_loss improved from 0.00221 to 0.00209, saving model to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1/cp-0002.ckpt
# 46/46 [==============================] - 1s 24ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 3/3
# 46/46 [==============================] - ETA: 0s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 3: val_loss improved from 0.00209 to 0.00192, saving model to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1/cp-0003.ckpt
# 46/46 [==============================] - 1s 26ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Tue Jun 24 11:35:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             30W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             24W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
#
# Adding early stopping params..
# Training stopped at epoch 0.
# Best epoch was -30, which corresponds to checkpoint -29
#
# Saving model..
# Model saved
#
# Total time to train and save model: 6.921836853027344 seconds
# Model: "ae"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  1564062
#
#  decoder (Decoder)           multiple                  1565046
#
# =================================================================
# Total params: 1567622 (5.98 MB)
# Trainable params: 1566334 (5.98 MB)
# Non-trainable params: 1288 (5.03 KB)
# _________________________________________________________________
# None
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_0 (Dense)             multiple                  1493504
#
#  dense_1 (Dense)             multiple                  67716
#
#  batch_norm_0 (BatchNormali  multiple                  2048
#  zation)
#
#  activation (Activation)     multiple                  0
#
#  batch_norm_1 (BatchNormali  multiple                  528
#  zation)
#
#  activation_1 (Activation)   multiple                  0
#
#  dense_latent (Dense)        multiple                  266
#
# =================================================================
# Total params: 1564062 (5.97 MB)
# Trainable params: 1562774 (5.96 MB)
# Non-trainable params: 1288 (5.03 KB)
# _________________________________________________________________
# None
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1_t (TiedDenseTransp  multiple                  68228
#  ose)
#
#  dense_latent_t (TiedDenseT  multiple                  398
#  ranspose)
#
#  dense_out (TiedDenseTransp  multiple                  1496420
#  ose)
#
#  dense_0 (Dense)             multiple                  1493504
#
#  dense_1 (Dense)             multiple                  67716
#
#  dense_latent (Dense)        multiple                  266
#
# =================================================================
# Total params: 1565046 (5.97 MB)
# Trainable params: 1565046 (5.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Starting plots
# Loss plots completed
# History saved to /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/latent_space/log_transformed_2916hvggenes/ae/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-24_11-35/splits_1/history.csv
#
# getting pca
# Calculating PCA ncomponents= 2
# plotting latent representation: X_pca_train
# unique_colorcol ['B' 'CTL' 'GMP' 'GMP-like' 'HSC' 'HSC-like' 'Mono' 'Mono-like' 'NK'
#  'Plasma' 'ProB' 'ProMono' 'ProMono-like' 'Prog' 'Prog-like' 'T' 'cDC'
#  'cDC-like' 'earlyEry' 'lateEry' 'pDC']
# plotting latent representation: X_pca_train
# unique_colorcol ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 ae = mods.AE()
#       6 # ae.model_params
# ----> 7 ae.run_train(named_experiment="AML", quick=True)
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/models/base.py:166, in Model.run_train(self, data_path, outputs_path, named_experiment, save_model, quick, plotconfigs, plot_kwargs)
#     160 celltype_ids = np.unique(metadata_all[params.bio_col]).tolist()
#     162 # --------------------------------------------------------------------------------------
#     163 # 3. Run All Folds
#     164 # --------------------------------------------------------------------------------------
#     165 # Run folds and compute clustering metrics
# --> 166 mean_scores = run_all_folds(
#     167     Model=self.alg,
#     168     input_base_path=splits_path,
#     169     out_base_paths_dict=base_paths_dict,
#     170     folds_list=params.fold_list,
#     171     run_name=params.run_name,
#     172     model_params_dict=self.model_params,
#     173     build_model_dict={k:v for k, v in self.model_configs._asdict().items() if k != "ignore"},
#     174     compile_dict=self.compile_configs,
#     175     save_model=save_model,
#     176     batch_col=params.batch_col,
#     177     bio_col=params.bio_col,
#     178     batch_col_categories=seen_donor_ids,
#     179     bio_col_categories=celltype_ids,
#     180     model_type=self.model_name,
#     181     issparse=False,
#     182     load_dense=False,
#     183     shape_color_dict=shape_color_dict,
#     184     sample_size=params.sample_size
#     185 )
#     187 # --------------------------------------------------------------------------------------
#     188 # 4. Save Configuration File
#     189 # --------------------------------------------------------------------------------------
#     190 destination_path = os.path.join(saved_models_base, params.run_name, "configs.json")
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:1474, in run_all_folds(Model, input_base_path, out_base_paths_dict, folds_list, run_name, model_params_dict, build_model_dict, compile_dict, save_model, batch_col, bio_col, batch_col_categories, bio_col_categories, model_type, issparse, load_dense, shape_color_dict, sample_size)
#    1469 print("\ninput_path_dict:\n", input_path_dict)
#    1470 # print("input_path_dict keys:", input_path_dict.keys())
#    1471
#    1472
#    1473 # Run pipeline for the current fold
# -> 1474 fold_results = run_model_pipeline(Model=Model,
#    1475                                   input_path_dict=input_path_dict,
#    1476                                   build_model_dict=build_model_dict,
#    1477                                   compile_dict=compile_dict,
#    1478                                   model_params=model_params,
#    1479                                   save_model=save_model,
#    1480                                   batch_col=batch_col,
#    1481                                   bio_col=bio_col,
#    1482                                   batch_col_categories=batch_col_categories,
#    1483                                   bio_col_categories=bio_col_categories,
#    1484                                   return_scores=return_scores_temp,
#    1485                                   return_adata_dict=True,
#    1486                                   return_trained_model=False,
#    1487                                   model_type=model_type,
#    1488                                   issparse=issparse,
#    1489                                   load_dense=load_dense,
#    1490                                   shape_color_dict=shape_color_dict,
#    1491                                   sample_size = sample_size,
#    1492                                   return_history=True)
#    1494 # add adata dictionaries per fold to all_folds_adata dict
#    1495 print("Output fold adata",fold_results["adata"])
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:1296, in run_model_pipeline(Model, input_path_dict, build_model_dict, compile_dict, model_params, save_model, batch_col, bio_col, batch_col_categories, bio_col_categories, return_scores, return_adata_dict, return_trained_model, model_type, issparse, load_dense, shape_color_dict, sample_size, return_history)
#    1294 if model_params.get_pca:
#    1295     print("\ngetting pca")
# -> 1296     adata_dict = get_pca_andplot(adata_dict, plot_params, eval_test=model_params.eval_test,shape_color_dict=shape_color_dict,n_components=model_params.n_components)
#    1298 # Initialize z_ohe_dict
#    1299 z_ohe_dict = None
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:1039, in get_pca_andplot(adata_dict, plot_params, eval_test, shape_color_dict, n_components)
#    1037         file_name = f"{shape_col}-{color_col}_{key}"
#    1038         specific_plot_params = {**plot_params, "file_name": file_name}
# -> 1039         plot_rep(adata, use_rep=pca_key, shape_col=shape_col, color_col=color_col, **specific_plot_params)
#    1041 # Additional generic plot for each type if needed outside the combinations
#    1042 # plot_rep(adata, use_rep=pca_key, **plot_params)
#    1043
#    1044 # Skip 'test' dataset unless eval_test is True
#    1045 if key == 'test' and not eval_test:
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/utils.py:491, in plot_rep(adata, shape_col, color_col, use_rep, markers, clustering_scores, save_fig, outpath, showplot, palette_choice, file_name)
#     489 for shape in unique_shapecol:
#     490     for color in unique_colorcol:
# --> 491         mask = (adata.obs[color_col] == color) & (adata.obs[shape_col] == shape)
#     492         ax.scatter(c1[mask], c2[mask], color=color_map[color], marker=shape_map[shape], alpha=0.7, s=1)
#     494 # Create legends
#
# File /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:293, in comparison_op(left, right, op)
#     290     return invalid_comparison(lvalues, rvalues, op)
#     292 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     295 else:
#     296     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:82, in comp_method_OBJECT_ARRAY(op, x, y)
#      80     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81 else:
# ---> 82     result = libops.scalar_compare(x.ravel(), y, op)
#      83 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
aec = mods.AEC()
aec.run_train(named_experiment="AML", quick=True)
# Out:
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Parent folder: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits
# Save model set to: True
# Number of batches: 19
# Ordered batches (donors): ['AML1012', 'AML210A', 'AML328', 'AML329', 'AML419A', 'AML420B', 'AML475', 'AML556', 'AML707B', 'AML870', 'AML916', 'AML921A', 'BM1', 'BM2', 'BM3', 'BM4', 'BM5', 'MUTZ3', 'OCI']
#
#
# Running Fold 1
#
#
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/figures/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/latent_space/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/figures/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
# Folder already exists: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/latent_space/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
# Current Model Parameters:
# optimizer: <keras.src.optimizers.legacy.adam.Adam object at 0x2aae56a713a0>
# loss: {'reconstruction_output': <keras.src.losses.MeanSquaredError object at 0x2aae56a71b20>, 'classification_output': <keras.src.losses.CategoricalCrossentropy object at 0x2aae56a71c10>}
# loss_weights: {'reconstruction_output': 100, 'classification_output': 0.1}
# metrics: {'reconstruction_output': [<keras.src.metrics.regression_metrics.MeanSquaredError object at 0x2aae56a87040>], 'classification_output': [<keras.src.metrics.accuracy_metrics.CategoricalAccuracy object at 0x2aaab63fd8b0>]}
# name: aec
# n_latent_dims: 2
# layer_units: [512, 132]
# layer_units_latent_classifier: [2]
# n_pred: 21
# last_activation: linear
# use_batch_norm: True
# eval_test: True
# use_z: False
# get_pred: False
# scaling: min_max
# fold_list: [1, 2, 3, 4, 5]
# model_type: aec
# batch_size: 512
# epochs: 3
# monitor_metric: val_loss
# patience: 30
# stop_criteria: early_stopping
# compute_latents_callback: False
# sample_size: 10000
# encoder_latent_name: None
# get_pca: True
# n_components: 2
# get_baseline: False
# batch_col: batch
# bio_col: celltype
# run_name: run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36
# model_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36
# plots_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/figures/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36
# latent_path_main: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/latent_space/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36
# model_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
# plots_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/figures/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
# latent_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/latent_space/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
# checkpoint_path: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1/cp-{epoch:04d}.ckpt
# checkpoint_dir: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/saved_models/log_transformed_2916hvggenes/aec/run_crossval_n_latent_dims-2_layer_units-512-132_n_pred-21_use_batch_norm-True_scaling-min_max_model_type-aec_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_2025-06-24_11-36/splits_1
#
# input_path_dict:
#  {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# input path dict {'train': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train', 'val': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val', 'test': '/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test'}
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/train
# X.shape before scaling (23049, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/val
# X.shape before scaling (7684, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading data from: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits/split_1/test
# X.shape before scaling (7684, 2916)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# loaded adata, adata_dict keys check: dict_keys(['train', 'val', 'test'])
# Batches available:  ['AML1012' 'AML210A' 'AML328' 'AML329' 'AML419A' 'AML420B' 'AML475'
#  'AML556' 'AML707B' 'AML870' 'AML916' 'AML921A' 'BM1' 'BM2' 'BM3' 'BM4'
#  'BM5' 'MUTZ3' 'OCI']
# check that the shapes make sense
# train out shape x: (23049, 2916)
# val out shape x: (7684, 2916)
# train in shape x: (23049, 2916)
# val in shape x: (7684, 2916)
# train_in shape x: (23049, 2916)
# train_out shape x: (23049, 2916)
# Tue Jun 24 11:36:25 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0             31W /  250W |    3092MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla P100-PCIE-16GB           Off |   00000000:82:00.0 Off |                    0 |
# | N/A   29C    P0             24W /  250W |       2MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      5558      C   ...chDL/shared/Day2Noon/env/bin/python       1210MiB |
# |    0   N/A  N/A     28958      C   ...cess/bin/glnxa64/pycli/MATLABPyHost       1626MiB |
# |    0   N/A  N/A     46545      C   ...ps/MATLAB/R2024a/bin/glnxa64/MATLAB        254MiB |
# +-----------------------------------------------------------------------------------------+
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 aec = mods.AEC()
# ----> 2 aec.run_train(named_experiment="AML", quick=True)
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/models/base.py:166, in Model.run_train(self, data_path, outputs_path, named_experiment, save_model, quick, plotconfigs, plot_kwargs)
#     160 celltype_ids = np.unique(metadata_all[params.bio_col]).tolist()
#     162 # --------------------------------------------------------------------------------------
#     163 # 3. Run All Folds
#     164 # --------------------------------------------------------------------------------------
#     165 # Run folds and compute clustering metrics
# --> 166 mean_scores = run_all_folds(
#     167     Model=self.alg,
#     168     input_base_path=splits_path,
#     169     out_base_paths_dict=base_paths_dict,
#     170     folds_list=params.fold_list,
#     171     run_name=params.run_name,
#     172     model_params_dict=self.model_params,
#     173     build_model_dict={k:v for k, v in self.model_configs._asdict().items() if k != "ignore"},
#     174     compile_dict=self.compile_configs,
#     175     save_model=save_model,
#     176     batch_col=params.batch_col,
#     177     bio_col=params.bio_col,
#     178     batch_col_categories=seen_donor_ids,
#     179     bio_col_categories=celltype_ids,
#     180     model_type=self.model_name,
#     181     issparse=False,
#     182     load_dense=False,
#     183     shape_color_dict=shape_color_dict,
#     184     sample_size=params.sample_size
#     185 )
#     187 # --------------------------------------------------------------------------------------
#     188 # 4. Save Configuration File
#     189 # --------------------------------------------------------------------------------------
#     190 destination_path = os.path.join(saved_models_base, params.run_name, "configs.json")
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:1474, in run_all_folds(Model, input_base_path, out_base_paths_dict, folds_list, run_name, model_params_dict, build_model_dict, compile_dict, save_model, batch_col, bio_col, batch_col_categories, bio_col_categories, model_type, issparse, load_dense, shape_color_dict, sample_size)
#    1469 print("\ninput_path_dict:\n", input_path_dict)
#    1470 # print("input_path_dict keys:", input_path_dict.keys())
#    1471
#    1472
#    1473 # Run pipeline for the current fold
# -> 1474 fold_results = run_model_pipeline(Model=Model,
#    1475                                   input_path_dict=input_path_dict,
#    1476                                   build_model_dict=build_model_dict,
#    1477                                   compile_dict=compile_dict,
#    1478                                   model_params=model_params,
#    1479                                   save_model=save_model,
#    1480                                   batch_col=batch_col,
#    1481                                   bio_col=bio_col,
#    1482                                   batch_col_categories=batch_col_categories,
#    1483                                   bio_col_categories=bio_col_categories,
#    1484                                   return_scores=return_scores_temp,
#    1485                                   return_adata_dict=True,
#    1486                                   return_trained_model=False,
#    1487                                   model_type=model_type,
#    1488                                   issparse=issparse,
#    1489                                   load_dense=load_dense,
#    1490                                   shape_color_dict=shape_color_dict,
#    1491                                   sample_size = sample_size,
#    1492                                   return_history=True)
#    1494 # add adata dictionaries per fold to all_folds_adata dict
#    1495 print("Output fold adata",fold_results["adata"])
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:1255, in run_model_pipeline(Model, input_path_dict, build_model_dict, compile_dict, model_params, save_model, batch_col, bio_col, batch_col_categories, bio_col_categories, return_scores, return_adata_dict, return_trained_model, model_type, issparse, load_dense, shape_color_dict, sample_size, return_history)
#    1253 # Train the model with appropriate data format
#    1254 if model_type == "aec":
# -> 1255     trained_model, history = train_and_save_model(model, train_in, train_out_dict, val_in, val_out_dict, model_params, save_model,metadata_dict)
#    1256 else:
#    1257     trained_model, history = train_and_save_model(model, train_in, train_out, val_in, val_out, model_params, save_model,metadata_dict)
#
# File /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/utils/model_train_utils.py:597, in train_and_save_model(model, train_in, train_out, val_in, val_out, model_params, save_model, metadata_dict)
#     595 print(os.system('nvidia-smi'))
#     596 # Train the model with the callbacks
# --> 597 history = model.fit(train_in, train_out, epochs=model_params.epochs,
#     598                     batch_size=model_params.batch_size,
#     599                     validation_data=(val_in, val_out),
#     600                     callbacks=callbacks)
#     601 print(os.system('nvidia-smi'))
#     603 if model_params.compute_latents_callback and metadata_dict:
#     604     # plot clustering scores curves
#
# File /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/keras/src/engine/data_adapter.py:1950, in _check_data_cardinality(data)
#    1943     msg += "  {} sizes: {}\n".format(
#    1944         label,
#    1945         ", ".join(
#    1946             str(i.shape[0]) for i in tf.nest.flatten(single_data)
#    1947         ),
#    1948     )
#    1949 msg += "Make sure all arrays contain the same number of samples."
# -> 1950 raise ValueError(msg)
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 23049
#   y sizes: 2916, 2916
# Make sure all arrays contain the same number of samples.

# %%
# import utils.defaults as defaults
# reload(defaults)
# import utils.defaults as defaults

# import utils.preprocessing as pp
# reload(pp)
# import utils.preprocessing as pp


reader = pp.AMLDataReader(defaults.AML_DATA_PATH)
