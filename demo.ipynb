# %%
import os
from importlib import reload

import models.models as mods
ae = mods.AE("ae")
# Out:
# 2025-06-23 16:10:13.368184: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-23 16:10:14.317921: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-23 16:10:14.321027: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-23 16:10:18.395427: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /archive/bioinformatics/DLLab/shared/CondaEnvironments/scMEDAL/lib/python3.8/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# ...

# %%
ae.model_params
# Out:
# {'optimizer': 'Adam',
#  'optimizer_configs': {'learning_rate': 0.001},
#  'loss': ['MeanSquaredError'],
#  'loss_configs': {'loss_weights': 1},
#  'metrics': ['MeanSquaredError'],
#  'metric_configs': None,
#  'name': 'ae',
#  'n_latent_dims': 2,
#  'layer_units': [512, 132],
#  'last_activation': 'linear',
#  'use_batch_norm': True,
#  'ignore': {'batch_col',
#   'bio_col',
#   'donor_col',
#   'encoder_latent_name',
#   'eval_test',
#   'fold_list',
#   'get_baseline',
#   'get_pca',
#   'get_pred',
#   'ignore',
#   'last_activation',
#   'layer_units_latent_classifier',
#   'loss',
#   'loss_configs',
#   'loss_weights',
#   'metric_configs',
#   'metrics',
#   'monitor_metric',
#   'name',
#   'optimizer',
#   'optimizer_configs',
#   'sigmoid_eval_test',
#   'stop_criteria',
#   'use_z'},
#  'eval_test': True,
#  'use_z': False,
#  'get_pred': False,
#  'scaling': 'min_max',
#  'fold_list': [1, 2, 3, 4, 5],
#  'model_type': 'ae',
#  'batch_size': 512,
#  'epochs': 500,
# ...

# %%
ae.run_train()
# Out:
# Parent folder: /archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/log_transformed_2916hvggenes/splits
# Save model set to: True
# Number of batches: 19
# Ordered batches (donors): ['AML1012', 'AML210A', 'AML328', 'AML329', 'AML419A', 'AML420B', 'AML475', 'AML556', 'AML707B', 'AML870', 'AML916', 'AML921A', 'BM1', 'BM2', 'BM3', 'BM4', 'BM5', 'MUTZ3', 'OCI']
#
#
# Running Fold 1
#
#
# Created folder: /endosome/archive/bioinformatics/DLLab/src/AustinMarckx/git/scMEDAL_for_scRNAseq/outputs/AML/saved_models/log_transformed_2916hvggenes/AE/run_crossval_n_latent_dims-2_layer_units-512-132_use_batch_norm-True_scaling-min_max_model_type-ae_batch_size-512_epochs-500_patience-30_compute_latents_callback-False_sample_size-10000_n_components-2_2025-06-23_16-10/splits_1
# ...

# %%
import utils.defaults as default
import pandas as pd
import glob
file = "/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/"

metadata_all = pd.read_csv(glob.glob(file + "/*meta.csv")[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 6
#       3 import glob
#       4 file = "/archive/bioinformatics/DLLab/AixaAndrade/src/gitfront/scMEDAL_for_scRNAseq/Experiments/data/AML_data/"
# ----> 6 metadata_all = pd.read_csv(glob.glob(file + "/*meta.csv")[0])
#
# IndexError: list index out of range

# %%
os.listdir(file)
# Out:
# ['._.DS_Store',
#  'preprocessed',
#  'adata_merged',
#  'zip_files',
#  '.DS_Store',
#  'cbioportal_AML_02052025',
#  'Supplemental_VanGallen2019',
#  'log_transformed_2916hvggenes']

# %%
tconfig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tconfig
#
# NameError: name 'tconfig' is not defined

# %%
import configs.configs as cfg
cfg.AEModelConfigs()
cfg.TrainingConfigs("ae")

# %%
# import utils.defaults as defaults
# reload(defaults)
# import utils.defaults as defaults

# import utils.preprocessing as pp
# reload(pp)
# import utils.preprocessing as pp


reader = pp.AMLDataReader(defaults.AML_DATA_PATH)
